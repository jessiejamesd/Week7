# %% [markdown]
# #**Q&A Activity Question Week -06**

# %% [markdown]
# ######***Importing necessary libraries***

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %% [markdown]
# ######***Reading dataset Dataset_w6.xlsx in to Python Environment using head(). The first 5 observations will be displayed.***

# %%
df=pd.read_excel('/content/gdrive/MyDrive/ICTAK/Week7_GroupActivity/Dataset_w6.xlsx')
df.head()
# Out:
#                country  ... International trade: Imports (million US$)
# 0          Afghanistan  ...                                       3568
# 1              Albania  ...                                       4669
# 2              Algeria  ...                                      47091
# 3               Angola  ...                                       8790
# 4  Antigua and Barbuda  ...                                        491
#
# [5 rows x 7 columns]

# %% [markdown]
# ######***Finding the no: of Observations***

# %%
df.shape
# Out:
# (196, 7)

# %% [markdown]
# ##**Insights:**
#
# > ***196 Observations found!***

# %% [markdown]
# ######***Checking for null values***

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [country, Region, Surface area (km2), Population in thousands (2017), GDP per capita (current US$), Agricultural production index , International trade: Imports (million US$)]
# Index: []

# %% [markdown]
# ##**Insights:**
#
# > ***No Null values Found!***

# %% [markdown]
# ##**1. Find out how many countries are there in the dataset.**

# %%
df['country'].unique().size
# Out:
# 196

# %% [markdown]
# ##**Insights:**
#
#
# > ***196 Countries Found!***

# %% [markdown]
# ##**3. Find out how many countries with respect to the region are available in the dataset**

# %%
df.loc[:,['Region','country']].groupby('Region').size().to_frame()
# Out:
#                     0
# Region
# Caribbean          16
# CentralAmerica      8
# CentralAsia         5
# EasternAfrica      17
# EasternAsia         7
# EasternEurope      10
# Melanesia           5
# Micronesia          4
# MiddleAfrica        9
# NorthernAfrica      5
# NorthernAmerica     4
# NorthernEurope     10
# Oceania             2
# Polynesia           5
# South-easternAsia  11
# SouthAmerica       12
# SouthernAfrica      5
# SouthernAsia        9
# SouthernEurope     12
# WesternAfrica      15
# WesternAsia        18
# WesternEurope       7

# %% [markdown]
# ##**4. On average which region has the highest**
#
#
# > a. GDP per capita (current US$)

# %%
df[['Region','GDP per capita (current US$)']].groupby('Region').mean().sort_values('GDP per capita (current US$)',ascending=False)
# Out:
#                    GDP per capita (current US$)
# Region
# NorthernAmerica                    57659.000000
# WesternEurope                      55387.128571
# Oceania                            44823.250000
# NorthernEurope                     42098.220000
# EasternAsia                        27967.614286
# WesternAsia                        17013.938889
# Caribbean                          15135.562500
# SouthernEurope                     14462.741667
# South-easternAsia                  10299.027273
# EasternEurope                       9292.490000
# Melanesia                           9261.960000
# Polynesia                           8686.520000
# SouthAmerica                        8499.775000
# CentralAmerica                      6348.137500
# Micronesia                          5008.300000
# CentralAsia                         4329.880000
# SouthernAfrica                      4191.900000
# NorthernAfrica                      3934.960000
# ...

# %% [markdown]
# ##**Insights:**
#
#
# > ***Northern America has the highest GDP per capita (current US$)***

# %% [markdown]
# ##**4. On average which region has the highest**
#
#
# > b. International trade: Imports (million US$)

# %%
df[['Region','International trade: Imports (million US$)']].groupby('Region').mean().sort_values('International trade: Imports (million US$)',ascending=False)
# Out:
#                    International trade: Imports (million US$)
# Region
# NorthernAmerica                                 663552.250000
# EasternAsia                                     451995.000000
# WesternEurope                                   407498.428571
# NorthernEurope                                  113407.200000
# Oceania                                         112914.500000
# South-easternAsia                                98324.636364
# EasternEurope                                    85243.900000
# SouthernEurope                                   76666.666667
# SouthernAsia                                     58199.333333
# CentralAmerica                                   57031.500000
# WesternAsia                                      46025.555556
# NorthernAfrica                                   35034.400000
# SouthAmerica                                     32885.666667
# SouthernAfrica                                   18005.600000
# ...

# %% [markdown]
# ##**Insights:**
#
#
# > ***NorthernAmerica has the highest International trade: Imports (million US$)***

# %% [markdown]
# ##**5. Find out which region has more consistent with respect to GDP per capita (current US$)**

# %%
df[['Region','GDP per capita (current US$)']].mode()
# Out:
#         Region  GDP per capita (current US$)
# 0  WesternAsia                        1106.4

# %% [markdown]
# ##**Insights:**
#
#
# > ***WesternAsia has more consistent with respect to GDP per capita***
